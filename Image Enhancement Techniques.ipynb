# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Image Negative:

# %%
image = cv2.imread('img5.jpg', 0)

# %%
# Image negative using built-in function
image_negative = 255 - image

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Image Negative')
plt.imshow(image_negative, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)

# %%
# User-defined funtion
def image_negative(image):
    return 255 - image

# %%
# Apply user-defined image negative function
negative_image = image_negative(image)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Image Negative')
plt.imshow(negative_image, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)

# %% [markdown]
# ### Gray Level Slicing:

# %%
# In-built function

# Define lower and upper threshold values
lower_thresh = 100
upper_thresh = 200

# %%
gray_slice = cv2.inRange(image, lower_thresh, upper_thresh)
gray_slice = np.where(output_image == 255, 255, 0).astype(np.uint8)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Gray Level Sliced Image')
plt.imshow(gray_slice, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)

# %%
# User-defined function

def gray_level_slicing(image, lower_thresh, upper_thresh):
    output_image = np.copy(image)
    output_image[(image > lower_thresh) & (image < upper_thresh)] = 255
    return output_image

# %%
sliced_image = gray_level_slicing(image, 100, 200)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Gray Level Sliced Image')
plt.imshow(sliced_image, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)

# %% [markdown]
# ### Histogram Equalization:

# %%
# Histogram equalization using built-in function
equalized_image = cv2.equalizeHist(image)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Histogram Equalization Image')
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)

# %%
#  User-defined function
def histogram_equalization(image):
    hist, bins = np.histogram(image.flatten(), 256, [0, 256])
    cdf = hist.cumsum()
    cdf_normalized = cdf * hist.max() / cdf.max()
    equalized_image = np.interp(image.flatten(), bins[:-1], cdf_normalized).reshape(image.shape).astype(np.uint8)
    return equalized_image

# %%
equalized = histogram_equalization(image)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(231)
plt.title('Original Grayscale')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(232)
plt.title('Histogram Equalization Image')
plt.imshow(equalized, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 639.5, 967.5, -0.5)
